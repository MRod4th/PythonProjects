# %%
w = ['gun', 'katana', 'hammer', 'truck', 'your mom']
zw = "katana"

print("there is a zombie, and you have to fight it. here are your weapon choises: ")
print(w)
print("type 1 if you want to chose from the list, and type 2 if you want to pick your own: ")
num=input()

if num == "1":
  print("ok")
  l=input("choose your weapon? ")
  if l== zw:
    print("you sliced up the zombie, and you defeated it.")
  if zw != l:
    print("you lost, and died")

elif num =="2":
  o=input('what is your weapon? ')
  w.append(o)
  if o == zw:
    print('you sliced up the zombie, and you defeated it.')
  else:
    print("you lost, and died")
# Out:
# there is a zombie, and you have to fight it. here are your weapon choises:
# ['gun', 'katana', 'hammer', 'truck', 'your mom']
# type 1 if you want to chose from the list, and type 2 if you want to pick your own:
# 2
# what is your weapon? asdf
# you lost, and died
